# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv("cleaned_customer_sales_data.csv")

# %%
df
# Out:
#      Customer_ID               Name  Gender   Age         City Signup_Date  \
# 0       CUST4371        Paul Wilson    Male  52.0     Kolkata   2025-06-26
# 1       CUST5957       Jason Thomas    Male  51.0     Kolkata   2021-02-17
# 2       CUST3754  Brittney Martinez  Female  62.0   Hyderabad   2023-11-05
# 3       CUST2934      Brenda Pierce  Female  40.0   Hyderabad   2022-03-13
# 4       CUST5683    Matthew Carroll  Female  41.0     Chennai   2024-04-05
# ...          ...                ...     ...   ...          ...         ...
# 9158    CUST6146      Cody Thompson  Female  40.0     Kolkata   2024-08-21
# 9159   CUST10767       Robert Lewis  Female  35.0       Delhi   2020-12-08
# 9160    CUST6315    Joshua Martinez    Male  25.0   Hyderabad   2022-02-15
# 9161    CUST4812       Sarah Miller  Female  55.0     Kolkata   2021-03-16
# 9162    CUST6588       David Potter  Female  34.0   Hyderabad   2020-10-12
#
#      Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# ...

# %%
df.duplicated().sum()
# 160
# Out:
# 160

# %%
df[(df["Age"] < 0) | (df["Age"] > 100)]
# Out:
#      Customer_ID             Name  Gender    Age         City Signup_Date  \
# 423     CUST6977      Tyler Stout  Female  250.0     Chennai   2022-05-21
# 847     CUST1207   Cathy Robinson  Female  250.0       Delhi   2024-10-24
# 2429    CUST1941   Virginia Casey    Male  -10.0     Chennai   2022-09-22
# 4753    CUST4536  Alexandra Ramos    Male  250.0     Chennai   2021-09-30
# 5358    CUST7041     Joseph Young    Male  250.0       Delhi   2022-01-20
# 5479    CUST8110       Betty Cole  Female  250.0   Bangalore   2024-01-07
# 5958   CUST10236    Brittney Boyd    Male  250.0     Kolkata   2022-04-01
# 6951    CUST3810    Meredith Shaw    Male  -10.0     Kolkata   2024-05-21
# 6980    CUST5388     Lauren Smith    Male  250.0     Chennai   2024-12-20
# 7500    CUST8792       Mark Meyer  Female  -10.0       Delhi   2022-03-29
#
#      Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# 423                 NaN           3554.0             2.0
# ...

# %%
df = df.drop_duplicates()

df.loc[(df["Age"] < 0) | (df["Age"] > 100), "Age"] = np.nan
df["Age"] = df["Age"].fillna(df["Age"].median())

df.loc[df["Purchase_Amount"] > 100000, "Purchase_Amount"] = np.nan
df["Purchase_Amount"] = df["Purchase_Amount"].fillna(df["Purchase_Amount"].median())

df["Last_Purchase_Date"] = df["Last_Purchase_Date"].fillna("Not Purchased Yet")

df["Signup_Date"] = pd.to_datetime(df["Signup_Date"])
# Out:
# C:\Users\sahub\AppData\Local\Temp\ipykernel_28524\1696334001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age"] = df["Age"].fillna(df["Age"].median())
# C:\Users\sahub\AppData\Local\Temp\ipykernel_28524\1696334001.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Purchase_Amount"] = df["Purchase_Amount"].fillna(df["Purchase_Amount"].median())
# C:\Users\sahub\AppData\Local\Temp\ipykernel_28524\1696334001.py:9: SettingWithCopyWarning:
# ...

# %%
# Out:
#      Customer_ID               Name  Gender   Age         City Signup_Date  \
# 0       CUST4371        Paul Wilson    Male  52.0     Kolkata   2025-06-26
# 1       CUST5957       Jason Thomas    Male  51.0     Kolkata   2021-02-17
# 2       CUST3754  Brittney Martinez  Female  62.0   Hyderabad   2023-11-05
# 3       CUST2934      Brenda Pierce  Female  40.0   Hyderabad   2022-03-13
# 4       CUST5683    Matthew Carroll  Female  41.0     Chennai   2024-04-05
# ...          ...                ...     ...   ...          ...         ...
# 9157    CUST6352       Isaiah Terry  Female  26.0     Kolkata   2023-03-04
# 9158    CUST6146      Cody Thompson  Female  40.0     Kolkata   2024-08-21
# 9159   CUST10767       Robert Lewis  Female  35.0       Delhi   2020-12-08
# 9160    CUST6315    Joshua Martinez    Male  25.0   Hyderabad   2022-02-15
# 9161    CUST4812       Sarah Miller  Female  55.0     Kolkata   2021-03-16
#
#      Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Country"].isnull().sum()
# Out:
# 0

# %%
(df["Country"].str.strip() == "").sum()
# Out:
# 0

# %%
df["Country"].isnull().sum() + (df["Country"].str.strip() == "").sum()
# Out:
# 0

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\sahub\OneDrive\Desktop\Intern Data Science\Customer_sales_dashboard\cleaned_customer_sales_data.csv"
)

print(df.head())
# Out:
#   Customer_ID               Name  Gender   Age         City Signup_Date  \
# 0    CUST4371        Paul Wilson    Male  52.0     Kolkata   2025-06-26
# 1    CUST5957       Jason Thomas    Male  51.0     Kolkata   2021-02-17
# 2    CUST3754  Brittney Martinez  Female  62.0   Hyderabad   2023-11-05
# 3    CUST2934      Brenda Pierce  Female  40.0   Hyderabad   2022-03-13
# 4    CUST5683    Matthew Carroll  Female  41.0     Chennai   2024-04-05
#
#   Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# 0         2025-05-17          26944.0             1.0
# 1         2025-07-22          44152.0             2.0
# 2         2024-12-08          31745.0             2.0
# 3         2025-10-02          39674.0             1.0
# 4         2024-12-15          24275.0             8.0
#
#                       Email  Phone_Number Country
# 0  peckvictoria@example.com    2131107701   India
# 1  owensanthony@example.com    1080761560   India
# 2        tara39@example.org    8981006345   India
# ...

# %%
df.to_csv(
    r"C:\Users\sahub\OneDrive\Desktop\Intern Data Science\Customer_sales_dashboard\cleaned_customer_sales_data.csv",
    index=False
)

# %%
df
# Out:
#      Customer_ID               Name  Gender   Age         City Signup_Date  \
# 0       CUST4371        Paul Wilson    Male  52.0     Kolkata   2025-06-26
# 1       CUST5957       Jason Thomas    Male  51.0     Kolkata   2021-02-17
# 2       CUST3754  Brittney Martinez  Female  62.0   Hyderabad   2023-11-05
# 3       CUST2934      Brenda Pierce  Female  40.0   Hyderabad   2022-03-13
# 4       CUST5683    Matthew Carroll  Female  41.0     Chennai   2024-04-05
# ...          ...                ...     ...   ...          ...         ...
# 9158    CUST6146      Cody Thompson  Female  40.0     Kolkata   2024-08-21
# 9159   CUST10767       Robert Lewis  Female  35.0       Delhi   2020-12-08
# 9160    CUST6315    Joshua Martinez    Male  25.0   Hyderabad   2022-02-15
# 9161    CUST4812       Sarah Miller  Female  55.0     Kolkata   2021-03-16
# 9162    CUST6588       David Potter  Female  34.0   Hyderabad   2020-10-12
#
#      Last_Purchase_Date  Purchase_Amount  Feedback_Score  \
# ...
